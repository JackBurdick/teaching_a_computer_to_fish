# %%
import pandas as pd
import os

# %% [markdown]
# ## Obtain different dataset data.gov
#
# https://catalog.data.gov/dataset

# %%
from six.moves import urllib

# where the datasets will be placed
ROOT_DATA = "../../../ROOT_DATA/data_gov/"

def fetch_data_from_URL(housing_url, file_name, sub_dir="tmp", root_path=ROOT_DATA):
    placement_dir = os.path.join(root_path, sub_dir)
    if not os.path.isdir(placement_dir):
        os.makedirs(placement_dir)
    placement_path = os.path.join(placement_dir, file_name)
    # only download if not already present
    if not os.path.isfile(placement_path):
        urllib.request.urlretrieve(housing_url, placement_path)
    return placement_path

# %%
# working with excel: `conda install -c anaconda xlrd`
fsa_xlsx_path = fetch_data_from_URL("https://ifap.ed.gov/fedschcodelist/attachments/1617FedSchoolCodeList.xlsx",
                    "1617FedSchoolCodeList.xlsx", sub_dir="FSA")

# %%
df = pd.read_excel(fsa_xlsx_path, index_col="ID")
df.drop(["PostalCode","Country","Province"], axis="columns", inplace=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6962 entries, 25969 to 32930
# Data columns (total 6 columns):
# SchoolCode    6962 non-null object
# SchoolName    6962 non-null object
# Address       6962 non-null object
# City          6962 non-null object
# StateCode     6962 non-null object
# ZipCode       6962 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 380.7+ KB
# None

# %% [markdown]
# ## Sample method

# %%
# will return one random row
df.sample()
# Out:
#       SchoolCode               SchoolName                    Address     City  \
# ID
# 26734     G08444  SIMON FRASER UNIVERSITY  8888 UNIVERSITY BOULEVARD  BURNABY
#
#       StateCode  ZipCode
# ID
# 26734        CN        0

# %%
df.sample(5)
# Out:
#       SchoolCode                                SchoolName  \
# ID
# 29291     005028  INTER AMERICAN UNIVERSITY OF PUERTO RICO
# 32037     039394                         CENTURA INSTITUTE
# 30630     014952                 HUMACAO COMMUNITY COLLEGE
# 29194     004549                 LEEWARD COMMUNITY COLLEGE
# 31691     031993                    CHRISTIAN LIFE COLLEGE
#
#                             Address            City StateCode  ZipCode
# ID
# 29291            CARRETERA 830 #500         BAYAMON        PR      957
# 32037  1300 NORTH SEMORAN BOULEVARD         ORLANDO        FL    32807
# 30630      ESMERALDA #7 PO BOX 9139         HUMACAO        PR      792
# 29194                96-045 ALA IKE      PEARL CITY        HI    96782
# 31691              400 E GREGORY ST  MOUNT PROSPECT        IL    60056

# %%
# will extract a percent
# 0.25 = 25%
df.sample(frac=0.001)
# Out:
#       SchoolCode                                SchoolName  \
# ID
# 26434     E01887     UNITED EDUCATION INSTITUTE - EL MONTE
# 31283     023166       CONNECTICUT CTR FOR MASSAGE THERAPY
# 26812     G10599         INST D'ETUDES POLITIQUES DE PARIS
# 27145     G39743  ST. GEORGE'S UNIVERSITY, SCHOOL OF VETER
# 28861     003571                 HARDIN-SIMMONS UNIVERSITY
# 29417     006257         SAINT ELIZABETH SCHOOL OF NURSING
# 29346     005424               SOUTH CENTRAL CAREER CENTER
#
#                       Address         City StateCode  ZipCode
# ID
# 26434   3401 RIO HONDO AVENUE     EL MONTE        CA    91731
# 31283             75 KITTS LN    NEWINGTON        CT     6111
# 26812  27 RUE SAINT-GUILLAUME        PARIS        FC        0
# 27145       UNIVERSITY CENTRE  ST.GEORGE'S        FC        0
# 28861               BOX 16050      ABILENE        TX    79698
# 29417  1508 TIPPECANOE STREET    LAFAYETTE        IN    47904
# 29346             610 E OLDEN  WEST PLAINS        MO    65775

# %%
df.sample(3)
# Out:
#       SchoolCode                        SchoolName                Address  \
# ID
# 32923     E40433  FLORIDA CAREER COLLEGE - KENDALL      11731 MILLS DRIVE
# 31334     026001     NEW YORK ACADEMY OF ART (THE)    111 FRANKLIN STREET
# 31464     030515  US GRANT JOINT VOCATIONAL SCHOOL  718 WEST PLANE STREET
#
#            City StateCode  ZipCode
# ID
# 32923     MIAMI        FL    33183
# 31334  NEW YORK        NY    10013
# 31464    BETHEL        OH    45106

# %%
# will extract three random columns from dataframe
df.sample(3, axis="columns")
# Out:
#       StateCode              City SchoolCode
# ID
# 25969        DE        WILMINGTON     B04724
# 25970        PR          SAN JUAN     B06171
# 25971        TN         CLEVELAND     B06511
# 25972        IL           CHICAGO     B07022
# 25973        OR          PORTLAND     B07624
# 25974        OR          PORTLAND     B07625
# 25975        MN           HOPKINS     B08041
# 25976        DC        WASHINGTON     B08083
# 25977        TX            CONROE     B42154
# 25978        MA         CAMBRIDGE     E00014
# 25979        RI        PROVIDENCE     E00058
# 25980        RI        PROVIDENCE     E00059
# 25981        PA        PITTSBURGH     E00073
# 25982        PA        PITTSBURGH     E00074
# 25983        OH         CLEVELAND     E00077
# 25984        OH         CLEVELAND     E00078
# 25985        OH         CLEVELAND     E00079
# 25986        OH         CLEVELAND     E00080
# 25987        OH         CLEVELAND     E00081
# 25988        OH         CLEVELAND     E00082
# 25989        OH         CLEVELAND     E00083
# 25990        OH         CLEVELAND     E00084
# 25991        DC        WASHINGTON     E00131
# 25992        IN          RICHMOND     E00170
# 25993        TN      JOHNSON CITY     E00171
# 25994        SC          DUE WEST     E00177
# 25995        DC        WASHINGTON     E00196
# 25996        DC        WASHINGTON     E00197
# 25997        MA         CAMBRIDGE     E00209
# 25998        MA         CAMBRIDGE     E00210
# ...         ...               ...        ...
# 32901        NJ          LAKEWOOD     042520
# 32902        FL  LAUDERDALE LAKES     042336
# 32903        IL    ROLLNG MEADOWS     042450
# 32904        IN      INDIANAPOLIS     042466
# 32905        PA        NORRISTOWN     042523
# 32906        CA       BAKERSFIELD     E40424
# 32907        IN      INDIANAPOLIS     042562
# 32908        NY              LIMA     042514
# 32909        IL          MATTESON     042428
# 32910        SC  NORTH CHARLESTON     042556
# 32911        OR          PORTLAND     G21544
# 32912        IN            CARMEL     042561
# 32913        AL           JACKSON     042555
# 32914        TN      MURFREESBORO     042531
# 32915        FL    PEMBROKE PINES     E40425
# 32916        FL   WEST PALM BEACH     E40426
# 32917        FL           HIALEAH     E40427
# 32918        FL  LAUDERDALE LAKES     E40428
# 32919        FL             TAMPA     E40429
# 32920        FL      JACKSONVILLE     E40430
# 32921        FL     BOYNTON BEACH     E40431
# 32922        FL           MARGATE     E40432
# 32923        FL             MIAMI     E40433
# 32924        FL           ORLANDO     E40434
# 32925        AZ           PHOENIX     E40435
# 32926        TX           HOUSTON     E40436
# 32927        CA            IRVINE     042496
# 32928        CA            FRESNO     042534
# 32929        OK        BROKEN BOW     042577
# 32930        NV         LAS VEGAS     042488
#
# [6962 rows x 3 columns]
