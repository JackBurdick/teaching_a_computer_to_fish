# %%
import pandas as pd
import os

# %% [markdown]
# ## Obtain different dataset data.gov
#
# https://catalog.data.gov/dataset

# %%
from six.moves import urllib

# where the datasets will be placed
ROOT_DATA = "../../../ROOT_DATA/data_gov/"

def fetch_data_from_URL(housing_url, file_name, sub_dir="tmp", root_path=ROOT_DATA):
    placement_dir = os.path.join(root_path, sub_dir)
    if not os.path.isdir(placement_dir):
        os.makedirs(placement_dir)
    placement_path = os.path.join(placement_dir, file_name)
    # only download if not already present
    if not os.path.isfile(placement_path):
        urllib.request.urlretrieve(housing_url, placement_path)
    return placement_path

# %%
# working with excel: `conda install -c anaconda xlrd`
fsa_xlsx_path = fetch_data_from_URL("https://ifap.ed.gov/fedschcodelist/attachments/1617FedSchoolCodeList.xlsx",
                    "1617FedSchoolCodeList.xlsx", sub_dir="FSA")

# %%
s_df = pd.read_excel(fsa_xlsx_path)
print(s_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6962 entries, 0 to 6961
# Data columns (total 10 columns):
# ID            6962 non-null int64
# SchoolCode    6962 non-null object
# SchoolName    6962 non-null object
# Address       6962 non-null object
# City          6962 non-null object
# StateCode     6962 non-null object
# ZipCode       6962 non-null int64
# Province      111 non-null object
# Country       402 non-null object
# PostalCode    229 non-null object
# dtypes: int64(2), object(8)
# memory usage: 544.0+ KB
# None

# %%
s_df.head()
# Out:
#       ID SchoolCode                             SchoolName  \
# 0  25969     B04724        WIDENER UNIV SCHOOL OF LAW - DE
# 1  25970     B06171    CENTER FOR ADVANCED STUDIES OF PUER
# 2  25971     B06511       PENTECOSTAL THEOLOGICAL SEMINARY
# 3  25972     B07022  THE CHICAGO SCHOOL OF PROF PSYCHOLOGY
# 4  25973     B07624   NATIONAL COLLEGE OF NATURAL MEDICINE
#
#                          Address        City StateCode  ZipCode Province  \
# 0  4601 CONCORD PIKE/PO BOX 7474  WILMINGTON        DE    19803      NaN
# 1                     BOX S-4467    SAN JUAN        PR      902      NaN
# 2                    PO BOX 3330   CLEVELAND        TN    37320      NaN
# 3         325 NORTH WELLS STREET     CHICAGO        IL    60610      NaN
# 4                  049 SW PORTER    PORTLAND        OR    97201      NaN
#
#   Country PostalCode
# 0     NaN        NaN
# 1     NaN        NaN
# 2     NaN        NaN
# 3     NaN        NaN
# 4     NaN        NaN

# %% [markdown]
# ## Sort
#
# Note:
#
# 1. `sort_values()` does not sort `inplace` by default
# 2. `NaN` values are placed at the "end" by default, regardless of ascending|descending
#  - can be adjusted with the `na_position=` param

# %%
s_df.sort_values("Country").head()
# Out:
#          ID SchoolCode                                SchoolName  \
# 6885  32854     042401  AMERICAN UNIVERSITY OF ANTIGUA COLLEGE O
# 1228  27197     G42194             UNIVERSIDAD TORCUATO DI TELLA
# 1068  27037     G31048                       GRIFFITH UNIVERSITY
# 1065  27034     G31000              UNIVERSITY OF ADELAIDE (THE)
# 1064  27033     G30961                       LA TROBE UNIVERSITY
#
#                              Address             City StateCode  ZipCode  \
# 6885                 UNIVERSITY PARK         COOLIDGE        FC        0
# 1228       AV. FIGUEROA ALCORTA 7350     BUENOS AIRES        FC        0
# 1068               GOLD COAST CAMPUS  QUEENSLAND 4211        FC        0
# 1065                              **         ADELAIDE        FC        0
# 1064  BUNDORA CAMPUS LA TROBE UNIVER         BUNDOORA        FC        0
#
#           Province    Country PostalCode
# 6885     ST.JOHN'S    ANTIGUA        NaN
# 1228  BUENOS AIRES  ARGENTINA       1428
# 1068           NaN  AUSTRALIA        NaN
# 1065           NaN  AUSTRALIA        NaN
# 1064           NaN  AUSTRALIA        NaN

# %%
s_df.sort_values("Country", ascending=False).head()
# Out:
#          ID SchoolCode                              SchoolName  \
# 768   26737     G08452                  ABERYSTWYTH UNIVERSITY
# 1113  27082     G34783  ROYAL WELSH COLLEGE OF MUSIC AND DRAMA
# 1129  27098     G35473               UNIVERSITY OF SOUTH WALES
# 774   26743     G08586                      SWANSEA UNIVERSITY
# 841   26810     G10589                       BANGOR UNIVERSITY
#
#                            Address         City StateCode  ZipCode  \
# 768                    OLD COLLEGE  ABERYSTWYTH        FC        0
# 1113  CASTLE GROUNDS, CATHAYS PARK      CARDIFF        FC        0
# 1129      LLANTWIT ROAD, TREFOREST   PONTYPRIDD        FC        0
# 774              ACADEMIC REGISTRY      SWANSEA        FC        0
# 841                         BANGOR      GWYNEDD        FC        0
#
#          Province Country PostalCode
# 768           NaN   WALES   SY23 2AX
# 1113          NaN   WALES   CF10 3ER
# 1129  SOUTH WALES   WALES   CF37 1DL
# 774           NaN   WALES    SA2 8PP
# 841           NaN   WALES   LL57 2DG

# %% [markdown]
# ## Sort by multiple values

# %%
# will sort by the order they are supplied in the list
s_df.sort_values(["Country","Province"]).head(6)
# Out:
#          ID SchoolCode                                SchoolName  \
# 6885  32854     042401  AMERICAN UNIVERSITY OF ANTIGUA COLLEGE O
# 1228  27197     G42194             UNIVERSIDAD TORCUATO DI TELLA
# 846   26815     G10681                      MACQUARIE UNIVERSITY
# 777   26746     G08670             UNIVERSITY OF NEW SOUTH WALES
# 1049  27018     G30672                      UNIVERSITY OF SYDNEY
# 1073  27042     G31406                 SOUTHERN CROSS UNIVERSITY
#
#                           Address                     City StateCode  ZipCode  \
# 6885              UNIVERSITY PARK                 COOLIDGE        FC        0
# 1228    AV. FIGUEROA ALCORTA 7350             BUENOS AIRES        FC        0
# 846          BUILDING E3A LEVEL 1          NEW SOUTH WALES        FC        0
# 777           GATE 9, HIGH STREET             UNSW, SYDNEY        FC        0
# 1049  VICE-CHANCELLOR OFFICE, A14  THE UNIVERSITY OF SYDNE        FC        0
# 1073                MILITARY ROAD             EAST LISMORE        FC        0
#
#              Province    Country PostalCode
# 6885        ST.JOHN'S    ANTIGUA        NaN
# 1228     BUENOS AIRES  ARGENTINA       1428
# 846   NEW SOUTH WALES  AUSTRALIA       2109
# 777               NSW  AUSTRALIA       2052
# 1049              NSW  AUSTRALIA       2006
# 1073              NSW  AUSTRALIA       2480

# %%
# it's possible to set the ascending value to different values for each
s_df.sort_values(["Country","Province"], ascending=[True, False], inplace=True)

# %%
s_df.head()
# Out:
#          ID SchoolCode                                SchoolName  \
# 6885  32854     042401  AMERICAN UNIVERSITY OF ANTIGUA COLLEGE O
# 1228  27197     G42194             UNIVERSIDAD TORCUATO DI TELLA
# 882   26851     G11094     UNIVERSITY OF WESTERN AUSTRALIA (THE)
# 847   26816     G10692            UNIVERSITY OF QUEENSLAND (THE)
# 907   26876     G12206                     JAMES COOK UNIVERSITY
#
#                                   Address          City StateCode  ZipCode  \
# 6885                      UNIVERSITY PARK      COOLIDGE        FC        0
# 1228            AV. FIGUEROA ALCORTA 7350  BUENOS AIRES        FC        0
# 882                   35 STIRLING HIGHWAY      NEDLANDS        FC        0
# 847   INTERNATIONAL EDUCATION DIRECTORATE      BRISBANE        FC        0
# 907                        DOUGLAS CAMPUS    TOWNSVILLE        FC        0
#
#                Province    Country PostalCode
# 6885          ST.JOHN'S    ANTIGUA        NaN
# 1228       BUENOS AIRES  ARGENTINA       1428
# 882   WESTERN AUSTRALIA  AUSTRALIA       6009
# 847          QUEENSLAND  AUSTRALIA       4072
# 907          QUEENSLAND  AUSTRALIA       4811

# %%
## `Soe

# %%
s_df.sort_index(inplace=True)
s_df.head()
# Out:
#       ID SchoolCode                             SchoolName  \
# 0  25969     B04724        WIDENER UNIV SCHOOL OF LAW - DE
# 1  25970     B06171    CENTER FOR ADVANCED STUDIES OF PUER
# 2  25971     B06511       PENTECOSTAL THEOLOGICAL SEMINARY
# 3  25972     B07022  THE CHICAGO SCHOOL OF PROF PSYCHOLOGY
# 4  25973     B07624   NATIONAL COLLEGE OF NATURAL MEDICINE
#
#                          Address        City StateCode  ZipCode Province  \
# 0  4601 CONCORD PIKE/PO BOX 7474  WILMINGTON        DE    19803      NaN
# 1                     BOX S-4467    SAN JUAN        PR      902      NaN
# 2                    PO BOX 3330   CLEVELAND        TN    37320      NaN
# 3         325 NORTH WELLS STREET     CHICAGO        IL    60610      NaN
# 4                  049 SW PORTER    PORTLAND        OR    97201      NaN
#
#   Country PostalCode
# 0     NaN        NaN
# 1     NaN        NaN
# 2     NaN        NaN
# 3     NaN        NaN
# 4     NaN        NaN
